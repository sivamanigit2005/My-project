# %% [markdown]
# <a href="https://colab.research.google.com/github/sivamanigit2005/My-project/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
data=[4,23,45,67,89] # Changed from set to list

q1=np.percentile(data,25)
q3=np.percentile(data,75)

Iqr=q3-q1

print("q1",q1)
print("q3:",q3)
print("intellegence range:",Iqr)
# Out:
# q1 23.0
# q3: 67.0
# intellegence range: 44.0
