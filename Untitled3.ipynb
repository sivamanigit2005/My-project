# %% [markdown]
# <a href="https://colab.research.google.com/github/sivamanigit2005/My-project/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mu = 0
sigma = 1
data = np.random.normal(mu, sigma, 1000)

x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)

pdf = norm.pdf(x, mu, sigma)

plt.figure(figsize=(10, 6))
plt.hist(data, bins=30, density=True, alpha=0.6, color='g', label='Histogram of Data')
plt.plot(x, pdf, 'r-', lw=2, label='Normal Distribution PDF')
plt.title('Normal Distribution Curve and Histogram')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()
